# %%
import numpy as np
import os
rootDir = '.'
for dirName,  subdirList, fileList in os.walk(rootDir):
    print('Found directory: %s' % dirName)
    for  fname in fileList:
        print ('\t%s' % fname)
        
import matplotlib.pylab as plt
from PIL import Image
import glob
import os


image_list = []
resized_images = []

for filename in glob.glob(r'\Users\faroo\Desktop\piaic\piaic Q2\photos\*.jpg'):
    img = Image.open(filename)
    image_list.append(img)
for image in image_list:
    res = image.resize((200,200))
    resized_images.append(res)
    
print(resized_images) 

#print(res)

i = 0
for (i,new) in enumerate(resized_images):
    new.save('{}{}{}'.format(r'\Users\faroo\Desktop\piaic\piaic Q2\new', i + 1,'.jpg'))
        
img1 =Image.open("new1.jpg")
img1.show()
print(img1)


np_img = np.array(img)
print(np_img)
print(np_img.shape)
# Out:
# Found directory: .
# 	06-10-19.ipynb
# 	22-09-2019.ipynb
# 	29-9-19.ipynb
# 	image numpy assignment.ipynb
# 	new1.jpg
# 	new10.jpg
# 	new11.jpg
# 	new12.jpg
# 	new13.jpg
# 	new14.jpg
# 	new15.jpg
# 	new16.jpg
# 	new17.jpg
# 	new18.jpg
# 	new19.jpg
# 	new2.jpg
# 	new20.jpg
# 	new3.jpg
# 	new4.jpg
# 	new5.jpg
# 	new6.jpg
# 	new7.jpg
# 	new8.jpg
# 	new9.jpg
# 	Numpy Tasks.ipynb
# 	Untitled.ipynb
# 	Untitled1.ipynb
# Found directory: .\.ipynb_checkpoints
# 	06-10-19-checkpoint.ipynb
# 	22-09-2019-checkpoint.ipynb
# 	29-9-19-checkpoint.ipynb
# 	image numpy assignment-checkpoint.ipynb
# 	Numpy Tasks-checkpoint.ipynb
# 	Untitled-checkpoint.ipynb
# 	Untitled1-checkpoint.ipynb
# Found directory: .\farooq
# 	new1.jpg
# 	new10.jpg
# 	new11.jpg
# 	new12.jpg
# 	new13.jpg
# 	new14.jpg
# 	new15.jpg
# 	new16.jpg
# 	new17.jpg
# 	new18.jpg
# 	new19.jpg
# 	new2.jpg
# 	new20.jpg
# 	new3.jpg
# 	new4.jpg
# 	new5.jpg
# 	new6.jpg
# 	new7.jpg
# 	new8.jpg
# 	new9.jpg
# Found directory: .\photos
# 	aeroplane.jpg
# 	baloon.jpg
# 	books.jpg
# 	car.jpg
# 	child.jpg
# 	cloud.jpg
# 	cycle.jpg
# 	flower.jpg
# 	glass.jpg
# 	house.jpg
# 	island.jpg
# 	jungle.jpg
# 	mountain.jpg
# 	nature.jpg
# 	road.jpg
# 	sunset.jpg
# 	swiming pool.jpg
# 	taxi.jpg
# 	tree.jpg
# 	waterfall.jpg
# Found directory: .\photos\.ipynb_checkpoints
# [<PIL.Image.Image image mode=RGB size=200x200 at 0x1688D14EDD8>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F0322E8>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F032208>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F0322B0>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F032C18>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F032080>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F032390>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F032908>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F0324A8>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F032588>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F0325F8>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F032668>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F0326D8>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F032748>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F032898>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F01EDA0>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F01ED68>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F01E8D0>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F01EE80>, <PIL.Image.Image image mode=RGB size=200x200 at 0x1688F08A860>]
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x1688F08A898>
# [[[ 65  88  44]
#   [ 72  98  53]
#   [ 81 106  64]
#   ...
#   [152  97  40]
#   [119  68  21]
#   [ 98  54   9]]
#
#  [[ 68  93  51]
#   [ 75 100  58]
#   [ 90 117  74]
#   ...
#   [151  96  39]
#   [114  63  16]
#   [113  69  24]]
#
#  [[ 35  62  21]
#   [ 61  87  48]
#   [ 90 118  78]
#   ...
#   [172 117  61]
#   [155 103  56]
#   [119  75  30]]
#
#  ...
#
#  [[ 58  73   0]
#   [ 84  99   6]
#   [ 98 113  20]
#   ...
#   [ 91  35   0]
#   [ 83  28   0]
#   [153 102  21]]
#
#  [[ 37  54   0]
#   [ 47  64   0]
#   [ 78  95   0]
#   ...
#   [139 100  25]
#   [110  72   1]
#   [113  78  10]]
#
#  [[ 53  89   1]
#   [ 66  82   9]
#   [ 72  72  10]
#   ...
#   [162 108  12]
#   [173 122  33]
#   [122  73   0]]]
# (177, 284, 3)
